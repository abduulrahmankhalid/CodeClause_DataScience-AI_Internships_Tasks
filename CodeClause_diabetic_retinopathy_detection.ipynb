# %% [markdown]
# #**Code Clause Data Science Intership**
# #**Project 2 : Diabetic Retinopathy Detection**
# #**Author : Abdulrahman Khalid**

# %% [markdown]
# **Importing Necassary Libraries**

# %%
from tensorflow import lite
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
import random, os
import cv2
import shutil
import keras
import matplotlib.pyplot as plt
from matplotlib.image import imread
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.metrics import categorical_accuracy
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Mapping Classes to Data**

# %%
df = pd.read_csv("../input/diabetic-retinopathy-224x224-gaussian-filtered/train.csv")

diagnosis_binary = {
        0: 'No_DR',
        1: 'DR',
        2: 'DR',
        3: 'DR',
        4: 'DR'}

diagnosis_classes = {
    0: 'No_DR',
    1: 'Mild',
    2: 'Moderate',
    3: 'Severe',
    4: 'Proliferate_DR',
}


df["binary"] = df["diagnosis"].map(diagnosis_binary.get)
df["type"] = df["diagnosis"].map(diagnosis_classes.get)

# %% [markdown]
# **Data Visualization**

# %%
df.head()
# Out:
#         id_code  diagnosis binary            type
# 0  000c1434d8d7          2     DR        Moderate
# 1  001639a390f0          4     DR  Proliferate_DR
# 2  0024cdab0c1e          1     DR            Mild
# 3  002c21358ce6          0  No_DR           No_DR
# 4  005b95c28852          0  No_DR           No_DR

# %%
df['type'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df['binary'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Data Preprocessing**

# %%
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from sklearn.preprocessing import LabelBinarizer
# !pip install imutils
from imutils import paths
from sklearn.utils import shuffle

# %% [markdown]
# >***Gathering Images and Lables***

# %%
data = []
labels = []
width,height=224,224

imagePaths = list(paths.list_images('../input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images'))

data = []
labels = []

for imagePath in imagePaths:
    label = imagePath.split(os.path.sep)[-2]   
    image = load_img(imagePath, target_size=(width, height))
    image = img_to_array(image)
    data.append(image)
    labels.append(label)

data = np.array(data, dtype="float32")
labels = np.array(labels)

lb = LabelBinarizer()
labels = lb.fit_transform(labels)

data, labels = shuffle(data, labels)

print(data.shape)
print(labels.shape)
# Out:
# (3662, 224, 224, 3)
# (3662, 5)

# %% [markdown]
# >***Normalizing the Data***

# %%
data = data / 255.0

# %% [markdown]
# **Splitting Data to Training , Validatoin and Testing Sets**

# %%
x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=.2)

print("Train images:",x_train.shape)
print("Test images:",x_test.shape)
print("Train label:",y_train.shape)
print("Test label:",y_test.shape)
# Out:
# Train images: (2929, 224, 224, 3)
# Test images: (733, 224, 224, 3)
# Train label: (2929, 5)
# Test label: (733, 5)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=.2)

print("Train images:",x_train.shape)
print("Test images:",x_val.shape)
print("Train label:",y_train.shape)
print("Test label:",y_val.shape)
# Out:
# Train images: (2343, 224, 224, 3)
# Test images: (586, 224, 224, 3)
# Train label: (2343, 5)
# Test label: (586, 5)

# %% [markdown]
# **Preparing VGG16 Pretrained Model**

# %%
from keras.models import Model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Activation, BatchNormalization, Dropout
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.applications.vgg16 import VGG16
from keras import layers

# %%
Vgg16 = VGG16(include_top=False, input_shape= (224,224,3)) 

Vgg16.trainable=False

# %% [markdown]
# **Fine-Tuning VGG16**

# %%
model = Sequential()
model.add(Vgg16)
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(64 , activation="relu"))
model.add(Dropout(0.25))
model.add(Dense(32 , activation="relu"))
#model.add(Dropout(0.25))
model.add(Dense(5 , activation="sigmoid"))

model.compile( optimizer="adam" , loss="binary_crossentropy" , metrics="binary_accuracy" )

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                1605696
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 165
# =================================================================
# Total params: 16,322,629
# Trainable params: 1,607,941
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
callbacks = [EarlyStopping(monitor='val_binary_accuracy' , patience=10 , restore_best_weights=True)]

history = model.fit(x_train , y_train , epochs=50 , batch_size=64,
                    validation_data=(x_val,y_val), verbose=1 , callbacks = callbacks)
# Out:
# 2022-09-18 23:45:38.893776: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 1410748416 exceeds 10% of free system memory.
# 2022-09-18 23:45:40.481651: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 1410748416 exceeds 10% of free system memory.
# 2022-09-18 23:45:41.609610: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 2022-09-18 23:45:43.288227: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 37/37 [==============================] - 22s 279ms/step - loss: 0.4019 - binary_accuracy: 0.8425 - val_loss: 0.2630 - val_binary_accuracy: 0.8945
# Epoch 2/50
# 37/37 [==============================] - 6s 156ms/step - loss: 0.2899 - binary_accuracy: 0.8836 - val_loss: 0.2443 - val_binary_accuracy: 0.9003
# Epoch 3/50
# 37/37 [==============================] - 6s 151ms/step - loss: 0.2698 - binary_accuracy: 0.8918 - val_loss: 0.2514 - val_binary_accuracy: 0.9007
# Epoch 4/50
# 37/37 [==============================] - 6s 153ms/step - loss: 0.2684 - binary_accuracy: 0.8903 - val_loss: 0.2351 - val_binary_accuracy: 0.9072
# Epoch 5/50
# 37/37 [==============================] - 6s 151ms/step - loss: 0.2558 - binary_accuracy: 0.8968 - val_loss: 0.2299 - val_binary_accuracy: 0.9116
# Epoch 6/50
# 37/37 [==============================] - 6s 153ms/step - loss: 0.2507 - binary_accuracy: 0.8978 - val_loss: 0.2244 - val_binary_accuracy: 0.9109
# Epoch 7/50
# 37/37 [==============================] - 6s 152ms/step - loss: 0.2483 - binary_accuracy: 0.8976 - val_loss: 0.2304 - val_binary_accuracy: 0.9102
# Epoch 8/50
# 37/37 [==============================] - 6s 153ms/step - loss: 0.2423 - binary_accuracy: 0.9029 - val_loss: 0.2227 - val_binary_accuracy: 0.9130
# Epoch 9/50
# 37/37 [==============================] - 6s 152ms/step - loss: 0.2344 - binary_accuracy: 0.9017 - val_loss: 0.2292 - val_binary_accuracy: 0.9075
# Epoch 10/50
# 37/37 [==============================] - 6s 152ms/step - loss: 0.2326 - binary_accuracy: 0.9016 - val_loss: 0.2407 - val_binary_accuracy: 0.9119
# Epoch 11/50
# 37/37 [==============================] - 6s 151ms/step - loss: 0.2342 - binary_accuracy: 0.9026 - val_loss: 0.2183 - val_binary_accuracy: 0.9130
# Epoch 12/50
# 37/37 [==============================] - 6s 153ms/step - loss: 0.2269 - binary_accuracy: 0.9035 - val_loss: 0.2181 - val_binary_accuracy: 0.9130
# Epoch 13/50
# 37/37 [==============================] - 6s 154ms/step - loss: 0.2252 - binary_accuracy: 0.9042 - val_loss: 0.2269 - val_binary_accuracy: 0.9116
# Epoch 14/50
# 37/37 [==============================] - 6s 152ms/step - loss: 0.2252 - binary_accuracy: 0.9047 - val_loss: 0.2195 - val_binary_accuracy: 0.9154
# Epoch 15/50
# 37/37 [==============================] - 6s 152ms/step - loss: 0.2248 - binary_accuracy: 0.9053 - val_loss: 0.2181 - val_binary_accuracy: 0.9133
# Epoch 16/50
# 37/37 [==============================] - 6s 154ms/step - loss: 0.2193 - binary_accuracy: 0.9070 - val_loss: 0.2190 - val_binary_accuracy: 0.9147
# Epoch 17/50
# 37/37 [==============================] - 6s 151ms/step - loss: 0.2128 - binary_accuracy: 0.9103 - val_loss: 0.2202 - val_binary_accuracy: 0.9177
# Epoch 18/50
# 37/37 [==============================] - 6s 153ms/step - loss: 0.2087 - binary_accuracy: 0.9102 - val_loss: 0.2215 - val_binary_accuracy: 0.9188
# Epoch 19/50
# 37/37 [==============================] - 6s 154ms/step - loss: 0.2094 - binary_accuracy: 0.9099 - val_loss: 0.2171 - val_binary_accuracy: 0.9191
# Epoch 20/50
# 37/37 [==============================] - 6s 153ms/step - loss: 0.2079 - binary_accuracy: 0.9108 - val_loss: 0.2135 - val_binary_accuracy: 0.9157
# Epoch 21/50
# 37/37 [==============================] - 6s 152ms/step - loss: 0.2031 - binary_accuracy: 0.9124 - val_loss: 0.2139 - val_binary_accuracy: 0.9126
# Epoch 22/50
# 37/37 [==============================] - 6s 154ms/step - loss: 0.2037 - binary_accuracy: 0.9106 - val_loss: 0.2214 - val_binary_accuracy: 0.9157
# Epoch 23/50
# 37/37 [==============================] - 6s 151ms/step - loss: 0.1997 - binary_accuracy: 0.9132 - val_loss: 0.2102 - val_binary_accuracy: 0.9208
# Epoch 24/50
# 37/37 [==============================] - 6s 155ms/step - loss: 0.1975 - binary_accuracy: 0.9163 - val_loss: 0.2323 - val_binary_accuracy: 0.9089
# Epoch 25/50
# 37/37 [==============================] - 6s 152ms/step - loss: 0.2013 - binary_accuracy: 0.9138 - val_loss: 0.2168 - val_binary_accuracy: 0.9106
# Epoch 26/50
# 37/37 [==============================] - 6s 151ms/step - loss: 0.2003 - binary_accuracy: 0.9121 - val_loss: 0.2136 - val_binary_accuracy: 0.9195
# Epoch 27/50
# 37/37 [==============================] - 6s 152ms/step - loss: 0.1937 - binary_accuracy: 0.9175 - val_loss: 0.2210 - val_binary_accuracy: 0.9137
# Epoch 28/50
# 37/37 [==============================] - 6s 154ms/step - loss: 0.2019 - binary_accuracy: 0.9134 - val_loss: 0.2197 - val_binary_accuracy: 0.9140
# Epoch 29/50
# 37/37 [==============================] - 6s 151ms/step - loss: 0.1907 - binary_accuracy: 0.9175 - val_loss: 0.2243 - val_binary_accuracy: 0.9171
# Epoch 30/50
# 37/37 [==============================] - 6s 156ms/step - loss: 0.1964 - binary_accuracy: 0.9163 - val_loss: 0.2202 - val_binary_accuracy: 0.9109
# Epoch 31/50
# 37/37 [==============================] - 6s 150ms/step - loss: 0.1893 - binary_accuracy: 0.9173 - val_loss: 0.2201 - val_binary_accuracy: 0.9157
# Epoch 32/50
# 37/37 [==============================] - 6s 153ms/step - loss: 0.1886 - binary_accuracy: 0.9189 - val_loss: 0.2295 - val_binary_accuracy: 0.9133
# Epoch 33/50
# 37/37 [==============================] - 6s 151ms/step - loss: 0.1877 - binary_accuracy: 0.9202 - val_loss: 0.2246 - val_binary_accuracy: 0.9174

# %% [markdown]
# **Evaluating the Model Performene**

# %%
def plot_curves(history):

  loss = history.history["loss"]
  val_loss = history.history["val_loss"]

  accuracy = history.history["binary_accuracy"]
  val_accuracy = history.history["val_binary_accuracy"]

  epochs = range(len(history.history["loss"]))

  #plot loss
  plt.plot(epochs, loss, label = "training_loss")
  plt.plot(epochs, val_loss, label = "val_loss")
  plt.title("loss")
  plt.xlabel("epochs")
  plt.legend()

  #plot accuracy
  plt.figure() 
  plt.plot(epochs, accuracy, label = "training_accuracy")
  plt.plot(epochs, val_accuracy, label = "val_accuracy")
  plt.title("accuracy")
  plt.xlabel("epochs")
  plt.legend()

# %%
plot_curves(history)

# %%
score = model.evaluate(x_test,y_test)
# Out:
# 23/23 [==============================] - 7s 186ms/step - loss: 0.2226 - binary_accuracy: 0.9102

# %% [markdown]
# > **Predicting Test Set**

# %%
pred = model.predict(x_test)
pred = np.argmax(pred,axis=1)

# %% [markdown]
# ***Visualizing a prediction***

# %%
index =5
predictions=["Mild","Moderate","NO_DR","Proliferate_DR","Severe"] 

img = x_test[index]
RGBImg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
RGBImg= cv2.resize(RGBImg,(224,224))

plt.imshow(RGBImg)
print(y_test[index]) # true
print(f"Prediction: {predictions[pred[index]]}") # predicted
# Out:
# [0 0 1 0 0]
# Prediction: NO_DR

# %% [markdown]
# **Predicting a new Sample**

# %%
import cv2

def predict_new(path):
    img = cv2.imread(path)

    RGBImg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    RGBImg= cv2.resize(RGBImg,(224,224))
    plt.imshow(RGBImg)
    image = np.array(RGBImg) / 255.0

    predict=model.predict(np.array([image]))
    pred=np.argmax(predict,axis=1)
    
    print(f"Predicted: {predictions[pred[0]]}")

# %%
predict_new("../input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Mild/01b3aed3ed4c.png")
#True --> Mild
# Out:
# Predicted: Mild
